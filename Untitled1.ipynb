# %% [markdown]
# # NuScenes 데이터셋 분포

# %% [markdown]
# ## 데이터셋 생성

# %%
from pkyutils import NusToolkit
    
toolkit = NusToolkit(root='/home/vilab/daehee/nus_dataset/original_small/v1.0-test', version='v1.0-test', load_dir='../nus_dataset')
toolkit.save_dataset()
# Out:
# import:
# pkyutils
# ======
# Loading NuScenes tables for version v1.0-test...
# 23 category,
# 8 attribute,
# 4 visibility,
# 0 instance,
# 12 sensor,
# 1800 calibrated_sensor,
# 462901 ego_pose,
# 15 log,
# 150 scene,
# 6008 sample,
# 462901 sample_data,
# 0 sample_annotation,
# 4 map,
# Done loading in 3.837 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 1.0 seconds.
# ======
#   0%|          | 0/6008 [00:00<?, ?it/s]num_samples: 6008
# /home/vilab/anaconda3/envs/datf/lib/python3.7/site-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)
#   2%|▏         | 114/6008 [00:30<26:38,  3.69it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4eb69f43e473> in <module>
#       2
#       3 toolkit = NusToolkit(root='/home/vilab/daehee/nus_dataset/original_small/v1.0-test', version='v1.0-test', load_dir='../nus_dataset')
# ----> 4 toolkit.save_dataset()
#
# ~/daehee/labs_hdmap/pkyutils.py in save_dataset(self)
#     302
#     303             for idx in tqdm(range(len(self.dataset))):
# --> 304                 map_masks, map_img, agent_mask, xy_local, virtual_mask, virtual_xy_local, idx = self.dataset[idx]
#     305
#     306                 agent_past, agent_future, agent_translation = xy_local
#
# ~/daehee/labs_hdmap/pkyutils.py in __getitem__(self, idx)
#     107         # 3. Generate Agent Trajectory
#     108         agent_mask, xy_global = self.agent_layer.generate_mask(
# --> 109             ego_pose_xy, ego_pose_rotation, sample_token, self.seconds, show_agent=self.show_agent)
#     110
#     111         xy_local = []
#
# ~/daehee/labs_hdmap/rasterization_q10/input_representation/agents.py in generate_mask(self, translation, rotation, sample_token, seconds, show_agent)
#     365
#     366         rotated_image = cv2.warpAffine(base_image, rotation_mat, (base_image.shape[1],
# --> 367                                                                   base_image.shape[0]))
#     368
#     369         row_crop, col_crop = get_crops(self.meters_ahead, self.meters_behind,
#
# KeyboardInterrupt:

# %% [markdown]
# ## 데이터 분포

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pkyutils import DatasetQ10

# %% [markdown]
# ### 1) 전체 에이전트

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../../jegyeong/datasets/nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='real', min_angle=None, max_angle=None)
dataset.show_distribution()
# Out:
# total agents: 171517
# 전체 episodes: 18167, 에이전트 개수: 171517
# episode 당 평균 에이전트 개수: 9.44
# 평균 경로 곡률: 0.54 (Deg)

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../../jegyeong/datasets/nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='fake', min_angle=None, max_angle=None)
dataset.show_distribution()
# Out:
# total agents: 156459
# 전체 episodes: 23866, 에이전트 개수: 156459
# episode 당 평균 에이전트 개수: 6.56
# 평균 경로 곡률: 5.85 (Deg)

# %% [markdown]
# ### 2) 상위 에이전트 제거 (1도)

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='real', min_angle=np.deg2rad(1), max_angle=None)
dataset.show_distribution()
# Out:
# total agents: 14451
# 전체 episodes: 8453, 에이전트 개수: 14451
# episode 당 평균 에이전트 개수: 1.71
# 평균 경로 곡률: 7.27 (Deg)

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='fake', min_angle=np.deg2rad(1), max_angle=None)
dataset.show_distribution()
# Out:
# total agents: 70867
# 전체 episodes: 19576, 에이전트 개수: 70867
# episode 당 평균 에이전트 개수: 3.62
# 평균 경로 곡률: 12.74 (Deg)

# %%
len(dataset.speeds)
# Out:
# 270721

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pkyutils import DatasetQ10

dataset = DatasetQ10(version='v1.0-trainval_val', load_dir='../nus_dataset',
                     shuffle=False, val_ratio=0.3, data_type='real', min_angle=None, max_angle=None)
dataset.show_speed_distribution()
dist = dataset.show_distance_distribution()
# Out:
# total agents: 198143
# 전체 episodes: 27853, 에이전트 개수: 198143
# episode 당 평균 에이전트 개수: 7.11
# 평균 에이전트 속도: 2.56 (m/s)
# 전체 episodes: 27853, 에이전트 개수: 198143
# episode 당 평균 에이전트 개수: 7.11
# 평균 에이전트 미래 주행거리: 6.24 (m)

# %%
from pkyutils import NusCustomParser

nusss = NusCustomParser(root='/home/vilab/jegyeong/datasets/nus_dataset/original_small/v1.0-trainval', version='v1.0-trainval')

nusss.render_sample(34)
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# 23 category,
# 8 attribute,
# 4 visibility,
# 64386 instance,
# 12 sensor,
# 10200 calibrated_sensor,
# 2631083 ego_pose,
# 68 log,
# 850 scene,
# 34149 sample,
# 2631083 sample_data,
# 1166187 sample_annotation,
# 4 map,
# Done loading in 28.019 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 8.2 seconds.
# ======
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-3402c33252c1> in <module>
#       3 nusss = NusCustomParser(root='/home/vilab/jegyeong/datasets/nus_dataset/original_small/v1.0-trainval', version='v1.0-trainval')
#       4
# ----> 5 nusss.render_sample(34)
#
# ~/daehee/labs_hdmap/pkyutils.py in render_sample(self, idx)
#     156         sample = self.samples[idx]
#     157         sample_token = sample['token']
# --> 158         self.nus.render_sample(sample_token)
#     159
#     160     def render_scene(self, idx):
#
# ~/anaconda3/envs/datf/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample(self, sample_token, box_vis_level, nsweeps, out_path, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose)
#     518                                     out_path=out_path, show_lidarseg=show_lidarseg,
#     519                                     filter_lidarseg_labels=filter_lidarseg_labels,
# --> 520                                     lidarseg_preds_bin_path=lidarseg_preds_bin_path, verbose=verbose)
#     521
#     522     def render_sample_data(self, sample_data_token: str, with_anns: bool = True,
#
# ~/anaconda3/envs/datf/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample(self, token, box_vis_level, nsweeps, out_path, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose)
#     986             for i, (_, sd_token) in enumerate(radar_data.items()):
#     987                 self.render_sample_data(sd_token, with_anns=i == 0, box_vis_level=box_vis_level, ax=ax, nsweeps=nsweeps,
# --> 988                                         verbose=False)
#     989             ax.set_title('Fused RADARs')
#     990
#
# ~/anaconda3/envs/datf/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose)
#    1159                 # Get aggregated radar point cloud in reference frame.
#    1160                 # The point cloud is transformed to the reference frame for visualization purposes.
# -> 1161                 pc, times = RadarPointCloud.from_file_multisweep(self.nusc, sample_rec, chan, ref_chan, nsweeps=nsweeps)
#    1162
#    1163                 # Transform radar velocities (x is front, y is left), as these are not transformed when loading the
#
# ~/anaconda3/envs/datf/lib/python3.7/site-packages/nuscenes/utils/data_classes.py in from_file_multisweep(cls, nusc, sample_rec, chan, ref_chan, nsweeps, min_distance)
#      97         for _ in range(nsweeps):
#      98             # Load up the pointcloud and remove points close to the sensor.
# ---> 99             current_pc = cls.from_file(osp.join(nusc.dataroot, current_sd_rec['filename']))
#     100             current_pc.remove_close(min_distance)
#     101
#
# ~/anaconda3/envs/datf/lib/python3.7/site-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name, invalid_states, dynprop_states, ambig_states)
#     382
#     383         meta = []
# --> 384         with open(file_name, 'rb') as f:
#     385             for line in f:
#     386                 line = line.strip().decode('utf-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vilab/jegyeong/datasets/nus_dataset/original_small/v1.0-trainval/samples/RADAR_FRONT/n015-2018-07-18-11-07-57+0800__RADAR_FRONT__1531883547575938.pcd'

# %%
print(len(dist))
np.array(np.array(dist)<=0.05, dtype=np.int).sum()
# Out:
# 270721
# 130374

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='real', min_angle=np.deg2rad(0.1), max_angle=None)
dataset.show_speed_distribution()
dataset.show_distance_distribution()
# Out:
# total agents: 24775
# 전체 episodes: 11981, 에이전트 개수: 24775
# episode 당 평균 에이전트 개수: 2.07
# 평균 에이전트 속도: 6.01 (m/s)
# 전체 episodes: 11981, 에이전트 개수: 24775
# episode 당 평균 에이전트 개수: 2.07
# 평균 에이전트 미래 주행거리: 14.69 (m)

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='fake', min_angle=None, max_angle=None)
dataset.show_speed_distribution()
dataset.show_distance_distribution()
# Out:
# total agents: 156459
# 전체 episodes: 23866, 에이전트 개수: 156459
# episode 당 평균 에이전트 개수: 6.56
# 평균 에이전트 속도: 5.02 (m/s)
# 전체 episodes: 23866, 에이전트 개수: 156459
# episode 당 평균 에이전트 개수: 6.56
# 평균 에이전트 미래 주행거리: 12.38 (m)

# %%
dataset = DatasetQ10(version='v1.0-trainval', load_dir='../nus_dataset', data_partition='train',
                     shuffle=False, val_ratio=0.3, data_type='fake', min_angle=np.deg2rad(0.1), max_angle=None)
dataset.show_speed_distribution()
dataset.show_distance_distribution()
# Out:
# total agents: 96679
# 전체 episodes: 21690, 에이전트 개수: 96679
# episode 당 평균 에이전트 개수: 4.46
# 평균 에이전트 속도: 5.01 (m/s)
# 전체 episodes: 21690, 에이전트 개수: 96679
# episode 당 평균 에이전트 개수: 4.46
# 평균 에이전트 미래 주행거리: 12.27 (m)
